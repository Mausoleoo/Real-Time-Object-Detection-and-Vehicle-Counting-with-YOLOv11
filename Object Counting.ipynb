# %%
import cv2

from ultralytics import solutions
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Mauricio\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
cap = cv2.VideoCapture("Aerial View.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# %%
region_points = [(690, 665), (950, 360), (680, 120), (440, 390)]


counter = solutions.ObjectCounter(
    show=True,
    region=region_points,
    model="yolo11n.pt",
    classes=[0, 1, 2, 3, 5],
)
# Out:
# Ultralytics Solutions:  {'region': [(680, 670), (950, 360), (680, 120), (440, 390)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'show': True, 'model': 'yolo11n.pt', 'classes': [0, 1, 2, 3, 5]}

# %%
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    im0 = counter.count(im0)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 persons, 29 cars, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 29 cars, 56.0ms
# Speed: 8.0ms preprocess, 56.0ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 31 cars, 57.3ms
# Speed: 6.5ms preprocess, 57.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 29 cars, 55.3ms
# Speed: 5.4ms preprocess, 55.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 28 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 24 cars, 32.1ms
# Speed: 8.2ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 29 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 30 cars, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 31 cars, 32.0ms
# Speed: 7.8ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 3 persons, 29 cars, 40.3ms
# Speed: 3.2ms preprocess, 40.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 28 cars, 32.0ms
# Speed: 8.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 32 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 36 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 car, 24.2ms
# Speed: 8.0ms preprocess, 24.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 3.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 31.8ms
# Speed: 0.0ms preprocess, 31.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.2ms
# Speed: 0.0ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.3ms
# Speed: 8.0ms preprocess, 40.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.1ms
# Speed: 0.0ms preprocess, 40.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.3ms
# Speed: 8.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.3ms
# Speed: 0.0ms preprocess, 40.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.5ms
# Speed: 0.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.3ms
# Speed: 8.0ms preprocess, 32.3ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.2ms
# Speed: 8.0ms preprocess, 40.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.1ms
# Speed: 8.0ms preprocess, 40.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.4ms
# Speed: 0.0ms preprocess, 40.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 7.8ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.0ms
# Speed: 8.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.1ms
# Speed: 8.0ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.3ms
# Speed: 0.0ms preprocess, 40.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.3ms
# Speed: 8.0ms preprocess, 24.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.2ms
# Speed: 8.0ms preprocess, 24.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 39.9ms
# Speed: 0.0ms preprocess, 39.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.2ms
# Speed: 7.8ms preprocess, 24.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 31.8ms
# Speed: 0.0ms preprocess, 31.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 23 cars, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 18 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 20 cars, 32.3ms
# Speed: 8.0ms preprocess, 32.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 26 cars, 40.1ms
# Speed: 0.0ms preprocess, 40.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 27 cars, 24.1ms
# Speed: 8.1ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 4 persons, 27 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 25 cars, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 27 cars, 40.3ms
# Speed: 0.0ms preprocess, 40.3ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 26 cars, 48.2ms
# Speed: 5.5ms preprocess, 48.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 25 cars, 40.2ms
# Speed: 0.0ms preprocess, 40.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 25 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 27 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 24 cars, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 24 cars, 40.1ms
# Speed: 0.0ms preprocess, 40.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 22 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 25 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 28 cars, 32.3ms
# Speed: 0.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 25 cars, 32.3ms
# Speed: 0.0ms preprocess, 32.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 26 cars, 32.4ms
# Speed: 8.0ms preprocess, 32.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 24 cars, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 26 cars, 32.3ms
# Speed: 8.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 23 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 22 cars, 40.1ms
# Speed: 0.0ms preprocess, 40.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 24 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 21 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 23 cars, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 23 cars, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 24 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 26 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 25 cars, 40.2ms
# Speed: 0.0ms preprocess, 40.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 27 cars, 24.1ms
# Speed: 8.1ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 31 cars, 24.2ms
# Speed: 7.9ms preprocess, 24.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 27 cars, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 27 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 29 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 27 cars, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 24 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 22 cars, 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 23 cars, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 25 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 26 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 26 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 28 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 30 cars, 24.1ms
# Speed: 7.8ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 30 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 31 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 30 cars, 35.0ms
# Speed: 0.0ms preprocess, 35.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 33 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 29 cars, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 34 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 31 cars, 40.1ms
# Speed: 8.0ms preprocess, 40.1ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 26 cars, 32.0ms
# Speed: 8.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 24 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 27 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 27 cars, 40.2ms
# Speed: 0.0ms preprocess, 40.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 25 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 22 cars, 24.4ms
# Speed: 8.0ms preprocess, 24.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 26 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 25 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 21 cars, 24.0ms
# Speed: 8.1ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 16 cars, 40.2ms
# Speed: 8.0ms preprocess, 40.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 20 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 19 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 18 cars, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 21 cars, 48.0ms
# Speed: 0.0ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 23 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 24 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 27 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 25 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 28 cars, 24.3ms
# Speed: 8.0ms preprocess, 24.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 29 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 33 cars, 40.1ms
# Speed: 8.0ms preprocess, 40.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 30 cars, 40.1ms
# Speed: 8.0ms preprocess, 40.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 29 cars, 40.1ms
# Speed: 8.0ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 27 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 27 cars, 32.3ms
# Speed: 8.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 29 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 33 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 34 cars, 40.2ms
# Speed: 8.0ms preprocess, 40.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 32 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 28 cars, 31.9ms
# Speed: 0.0ms preprocess, 31.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 26 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 27 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 27 cars, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 27 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 25 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 27 cars, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 21 cars, 24.1ms
# Speed: 7.9ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.3ms
# Speed: 8.0ms preprocess, 40.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 40.2ms
# Speed: 8.0ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 40.2ms
# Speed: 0.0ms preprocess, 40.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 8.1ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.3ms
# Speed: 0.0ms preprocess, 32.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.3ms
# Speed: 0.0ms preprocess, 32.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 40.2ms
# Speed: 0.0ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 20 cars, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 17 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 3 persons, 17 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 17 cars, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 19 cars, 48.5ms
# Speed: 0.0ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 18 cars, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 20 cars, 24.2ms
# Speed: 8.0ms preprocess, 24.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 20 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 23 cars, 32.1ms
# Speed: 7.8ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 23 cars, 32.3ms
# Speed: 8.1ms preprocess, 32.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 20 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 19 cars, 40.1ms
# Speed: 0.0ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 20 cars, 31.9ms
# Speed: 8.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 20 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 21 cars, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 24 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 22 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 18 cars, 48.3ms
# Speed: 0.0ms preprocess, 48.3ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 17 cars, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 18 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 16 cars, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 3 persons, 15 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 16 cars, 24.2ms
# Speed: 8.0ms preprocess, 24.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 3 persons, 17 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 14 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 3 persons, 19 cars, 48.6ms
# Speed: 16.0ms preprocess, 48.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 18 cars, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 19 cars, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 20 cars, 24.0ms
# Speed: 7.8ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 19 cars, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 3 persons, 21 cars, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.1ms
# Speed: 7.8ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24.0ms
# Speed: 7.8ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24.1ms
# Speed: 8.0ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.2ms
# Speed: 3.0ms preprocess, 48.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.0ms
# Speed: 8.0ms preprocess, 40.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.2ms
# Speed: 8.0ms preprocess, 40.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.1ms
# Speed: 8.0ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 20 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 23 cars, 32.2ms
# Speed: 8.0ms preprocess, 32.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 3 persons, 20 cars, 32.1ms
# Speed: 8.1ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 19 cars, 24.2ms
# Speed: 8.0ms preprocess, 24.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 20 cars, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 1 person, 19 cars, 24.0ms
# Speed: 7.6ms preprocess, 24.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 5 persons, 19 cars, 40.3ms
# Speed: 0.0ms preprocess, 40.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 4 persons, 19 cars, 24.1ms
# Speed: 7.7ms preprocess, 24.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
#
# 0: 384x640 2 persons, 22 cars, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  no tracks found!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 6
#       4         print("Video frame is empty or video processing has been successfully completed.")
#       5         break
# ----> 6     im0 = counter.count(im0)
#       7     video_writer.write(im0)
#       9 cap.release()
#
# File c:\Users\Mauricio\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\solutions\object_counter.py:185, in ObjectCounter.count(self, im0)
#     182     self.count_objects(self.track_line, box, track_id, prev_position, cls)  # Perform object counting
#     184 self.display_counts(im0)  # Display the counts on the frame
# --> 185 self.display_output(im0)  # display output with base class function
#     187 return im0
#
# File c:\Users\Mauricio\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\solutions\solutions.py:149, in BaseSolution.display_output(self, im0)
#     147 if self.CFG.get("show") and self.env_check:
#     148     cv2.imshow("Ultralytics Solutions", im0)
# --> 149     if cv2.waitKey(1) & 0xFF == ord("q"):
#     150         return
#
# KeyboardInterrupt:
